# %%
#Library Import
import pandas as pd #Used to work on Dataframes
import ast #To get a literal from a string of words
from nltk.stem.porter import PorterStemmer #To remove similar words from vectors
from sklearn.feature_extraction.text import CountVectorizer #To make a Bag of Words
from sklearn.metrics.pairwise import cosine_similarity #To compute similarity between two vectors

# %%
#Dataset Loading
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

#Check Credits Dataset
credits.head(5)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#Check Shapes of Dataframes
print(movies.shape)
print(credits.shape)

#Check the Movies Dataset
movies.head(5)
# Out:
# (4803, 20)
# (4803, 4)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
#Check Cast Values 
print(credits['cast'][1])

#Check Crew Values
print('\n\n',credits['crew'][1])

#Check Genre of Movies
print('\n\n', movies['genres'][1])

#Check Overview of Movies
print('\n\n', movies['overview'][1])
# Out:
# [{"cast_id": 4, "character": "Captain Jack Sparrow", "credit_id": "52fe4232c3a36847f800b50d", "gender": 2, "id": 85, "name": "Johnny Depp", "order": 0}, {"cast_id": 5, "character": "Will Turner", "credit_id": "52fe4232c3a36847f800b511", "gender": 2, "id": 114, "name": "Orlando Bloom", "order": 1}, {"cast_id": 6, "character": "Elizabeth Swann", "credit_id": "52fe4232c3a36847f800b515", "gender": 1, "id": 116, "name": "Keira Knightley", "order": 2}, {"cast_id": 12, "character": "William \"Bootstrap Bill\" Turner", "credit_id": "52fe4232c3a36847f800b52d", "gender": 2, "id": 1640, "name": "Stellan Skarsg\u00e5rd", "order": 3}, {"cast_id": 10, "character": "Captain Sao Feng", "credit_id": "52fe4232c3a36847f800b525", "gender": 2, "id": 1619, "name": "Chow Yun-fat", "order": 4}, {"cast_id": 9, "character": "Captain Davy Jones", "credit_id": "52fe4232c3a36847f800b521", "gender": 2, "id": 2440, "name": "Bill Nighy", "order": 5}, {"cast_id": 7, "character": "Captain Hector Barbossa", "credit_id": "52fe4232c3a36847f800b519", "gender": 2, "id": 118, "name": "Geoffrey Rush", "order": 6}, {"cast_id": 14, "character": "Admiral James Norrington", "credit_id": "52fe4232c3a36847f800b535", "gender": 2, "id": 1709, "name": "Jack Davenport", "order": 7}, {"cast_id": 13, "character": "Joshamee Gibbs", "credit_id": "52fe4232c3a36847f800b531", "gender": 2, "id": 2449, "name": "Kevin McNally", "order": 8}, {"cast_id": 11, "character": "Lord Cutler Beckett", "credit_id": "52fe4232c3a36847f800b529", "gender": 2, "id": 2441, "name": "Tom Hollander", "order": 9}, {"cast_id": 19, "character": "Tia Dalma", "credit_id": "52fe4232c3a36847f800b549", "gender": 1, "id": 2038, "name": "Naomie Harris", "order": 10}, {"cast_id": 8, "character": "Governor Weatherby Swann", "credit_id": "52fe4232c3a36847f800b51d", "gender": 2, "id": 378, "name": "Jonathan Pryce", "order": 11}, {"cast_id": 37, "character": "Captain Teague Sparrow", "credit_id": "52fe4232c3a36847f800b5b3", "gender": 2, "id": 1430, "name": "Keith Richards", "order": 12}, {"cast_id": 16, "character": "Pintel", "credit_id": "52fe4232c3a36847f800b53d", "gender": 2, "id": 1710, "name": "Lee Arenberg", "order": 13}, {"cast_id": 15, "character": "Ragetti", "credit_id": "52fe4232c3a36847f800b539", "gender": 2, "id": 1711, "name": "Mackenzie Crook", "order": 14}, {"cast_id": 18, "character": "Lieutenant Theodore Groves", "credit_id": "52fe4232c3a36847f800b545", "gender": 2, "id": 4031, "name": "Greg Ellis", "order": 15}, {"cast_id": 55, "character": "Cotton", "credit_id": "57e28d2ec3a3681a01005b5c", "gender": 2, "id": 1715, "name": "David Bailie", "order": 16}, {"cast_id": 17, "character": "Marty", "credit_id": "52fe4232c3a36847f800b541", "gender": 2, "id": 4030, "name": "Martin Klebba", "order": 17}, {"cast_id": 57, "character": "Ian Mercer", "credit_id": "57e28d78c3a36808b900bf4f", "gender": 0, "id": 939, "name": "David Schofield", "order": 18}, {"cast_id": 62, "character": "Scarlett", "credit_id": "57e28ec5c3a3681a50005855", "gender": 1, "id": 2450, "name": "Lauren Maher", "order": 19}, {"cast_id": 63, "character": "Giselle", "credit_id": "57e28ed692514123f5005635", "gender": 1, "id": 2452, "name": "Vanessa Branch", "order": 20}, {"cast_id": 60, "character": "Mullroy", "credit_id": "57e28db2c3a3681a01005bc7", "gender": 2, "id": 1714, "name": "Angus Barnett", "order": 21}, {"cast_id": 59, "character": "Murtogg", "credit_id": "57e28da192514118f7006008", "gender": 0, "id": 1713, "name": "Giles New", "order": 22}, {"cast_id": 58, "character": "Tai Huang", "credit_id": "57e28d8ec3a3681a01005bab", "gender": 2, "id": 22075, "name": "Reggie Lee", "order": 23}, {"cast_id": 64, "character": "Henry Turner", "credit_id": "57e29119925141151100a6cc", "gender": 2, "id": 61259, "name": "Dominic Scott Kay", "order": 24}, {"cast_id": 39, "character": "Mistress Ching", "credit_id": "52fe4232c3a36847f800b5bd", "gender": 1, "id": 33500, "name": "Takayo Fischer", "order": 25}, {"cast_id": 40, "character": "Lieutenant Greitzer", "c ...
#
#
#  [{"credit_id": "52fe4232c3a36847f800b579", "department": "Camera", "gender": 2, "id": 120, "job": "Director of Photography", "name": "Dariusz Wolski"}, {"credit_id": "52fe4232c3a36847f800b4fd", "department": "Directing", "gender": 2, "id": 1704, "job": "Director", "name": "Gore Verbinski"}, {"credit_id": "52fe4232c3a36847f800b54f", "department": "Production", "gender": 2, "id": 770, "job": "Producer", "name": "Jerry Bruckheimer"}, {"credit_id": "52fe4232c3a36847f800b503", "department": "Writing", "gender": 2, "id": 1705, "job": "Screenplay", "name": "Ted Elliott"}, {"credit_id": "52fe4232c3a36847f800b509", "department": "Writing", "gender": 2, "id": 1706, "job": "Screenplay", "name": "Terry Rossio"}, {"credit_id": "52fe4232c3a36847f800b57f", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "52fe4232c3a36847f800b585", "department": "Editing", "gender": 2, "id": 1722, "job": "Editor", "name": "Craig Wood"}, {"credit_id": "52fe4232c3a36847f800b573", "department": "Sound", "gender": 2, "id": 947, "job": "Original Music Composer", "name": "Hans Zimmer"}, {"credit_id": "52fe4232c3a36847f800b555", "department": "Production", "gender": 2, "id": 2444, "job": "Executive Producer", "name": "Mike Stenson"}, {"credit_id": "52fe4232c3a36847f800b561", "department": "Production", "gender": 2, "id": 2445, "job": "Producer", "name": "Eric McLeod"}, {"credit_id": "52fe4232c3a36847f800b55b", "department": "Production", "gender": 2, "id": 2446, "job": "Producer", "name": "Chad Oman"}, {"credit_id": "52fe4232c3a36847f800b567", "department": "Production", "gender": 0, "id": 2447, "job": "Producer", "name": "Peter Kohn"}, {"credit_id": "52fe4232c3a36847f800b56d", "department": "Production", "gender": 0, "id": 2448, "job": "Producer", "name": "Pat Sandston"}, {"credit_id": "52fe4232c3a36847f800b58b", "department": "Production", "gender": 1, "id": 2215, "job": "Casting", "name": "Denise Chamian"}, {"credit_id": "52fe4232c3a36847f800b597", "department": "Art", "gender": 2, "id": 1226, "job": "Production Design", "name": "Rick Heinrichs"}, {"credit_id": "52fe4232c3a36847f800b59d", "department": "Art", "gender": 2, "id": 553, "job": "Art Direction", "name": "John Dexter"}, {"credit_id": "52fe4232c3a36847f800b591", "department": "Production", "gender": 1, "id": 3311, "job": "Casting", "name": "Priscilla John"}, {"credit_id": "52fe4232c3a36847f800b5a3", "department": "Art", "gender": 1, "id": 4032, "job": "Set Decoration", "name": "Cheryl Carasik"}, {"credit_id": "52fe4232c3a36847f800b5a9", "department": "Costume & Make-Up", "gender": 0, "id": 4033, "job": "Costume Design", "name": "Liz Dann"}, {"credit_id": "52fe4232c3a36847f800b5af", "department": "Costume & Make-Up", "gender": 1, "id": 4034, "job": "Costume Design", "name": "Penny Rose"}, {"credit_id": "56427ce8c3a3686a53000d8b", "department": "Sound", "gender": 2, "id": 5132, "job": "Music Supervisor", "name": "Bob Badami"}, {"credit_id": "55993c15c3a36855db002f33", "department": "Art", "gender": 2, "id": 146439, "job": "Conceptual Design", "name": "James Ward Byrkit"}, {"credit_id": "52fe4232c3a36847f800b5b9", "department": "Costume & Make-Up", "gender": 1, "id": 406204, "job": "Makeup Department Head", "name": "Ve Neill"}, {"credit_id": "56e47f7892514132690017bd", "department": "Crew", "gender": 2, "id": 1259516, "job": "Stunts", "name": "John Dixon"}, {"credit_id": "5740be639251416597000849", "department": "Crew", "gender": 0, "id": 1336716, "job": "CGI Supervisor", "name": "Dottie Starling"}, {"credit_id": "56427c639251412fc8000dc1", "department": "Directing", "gender": 1, "id": 1344278, "job": "Script Supervisor", "name": "Pamela Alch"}, {"credit_id": "57083101c3a3681d320004e6", "department": "Crew", "gender": 0, "id": 1368867, "job": "Special Effects Coordinator", "name": "Allen Hall"}, {"credit_id": "56427d5ec3a3686a62000d4a", "department": "Sound", "gender": 0, "id": 1368884, "job": "Music Editor", "name": "Melissa Muik"}, {"credit_i ...
#
#
#  [{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]
#
#
#  Captain Barbossa, long believed to be dead, has come back to life and is headed to the edge of the Earth with Will Turner and Elizabeth Swann. But nothing is quite as it seems.

# %%
#Merge Movies and Credits together so we can work on a single dataframe
df = movies.merge(credits, on='title')
df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 23 columns]

# %%
#Get type and column info about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 901.7+ KB

# %%
#Checking Original Language 
languages = df['original_language'].value_counts()
print('Movies with English Language =', languages[0], 'which constitutes',languages[0]*100/languages.sum(), 'percent of the dataset')
# Out:
# Movies with English Language = 4510 which constitutes 93.78249116240383 percent of the dataset

# %%
#Since we are working on non-numeric data : budget, popularity, revenue, runtime, vote_average, vote_count is of no use...
#Though they are useful in determining next recommendation, but currently we are sticking purely to content based filtering
#They could be used to determine movies based on popularity or the trending ones but not on content wise

#HomePage doesn't make any sense for recommendation
#In Languages, english consitutes more than 90% of the dataset, so it won't make a big difference in the recommendation
#Release Dates might affect the recommendation, but content is more superior than year of release
#Production Countries and Companies don't reflect the raw contents of the movie
#Similarly for spoken languages, status and tagline, we avoided those for our movie recommendation

#Our new dataframe consisting only 7 columns
updated_df = df[['id', 'title', 'keywords', 'overview', 'genres', 'cast', 'crew']]
updated_df.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#Check Shape of the new dataframe
print(updated_df.shape)

#Check for Null Coloumns before dropping
updated_df.isnull().sum()
# Out:
# (4809, 7)
# id          0
# title       0
# keywords    0
# overview    3
# genres      0
# cast        0
# crew        0
# dtype: int64

# %%
#This line is used to turn off any warning messages from pandas
pd.set_option('mode.chained_assignment', None)

#Drop the null Columns (overview had 3 null rows)
updated_df.dropna(inplace = True)
print(updated_df.shape)

#Check for Null Columns after dropping (3 row has been removed from the dataframe)
updated_df.isnull().sum()
# Out:
# (4806, 7)
# id          0
# title       0
# keywords    0
# overview    0
# genres      0
# cast        0
# crew        0
# dtype: int64

# %%
#Some Dataset Transformations

#Check for the genre of the movie
print(updated_df.iloc[0].genres)

#Convert the dictionary by extracting the names of the genre
def extractor(ob): #Function to extract only the names
    words = []
    for i in ast.literal_eval(ob):
        words.append(i['name'])
    return words

#Update the Keywords and Genre by extracting only 
updated_df['genres'] = updated_df['genres'].apply(extractor)
updated_df['keywords'] = updated_df['keywords'].apply(extractor)

#Since we have so many casts in the picture, we take only the top 10 cast of the movies
def cast_extractor(ob):
    cast = []
    count = 0
    for i in ast.literal_eval(ob):
        if count != 10:     
            cast.append(i['name'])
            count += 1
        else:
            break
    return cast

#Update the Cast Column by top 10 Casts
updated_df['cast'] = updated_df['cast'].apply(cast_extractor)

#Get only the directors of the crew, as people sometimes lean towards the director of the film
def get_director(ob):
    director = []
    for i in ast.literal_eval(ob):
        if i['job'] == 'Director':
            director.append(i['name'])
            break
    return director
        
#Update the crew column with the director only
updated_df['crew'] = updated_df['crew'].apply(get_director)

#New Updated Dataset
updated_df.head(5)
# Out:
# [{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]

# %%
updated_df.head(5)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]

# %%
#Some splitting and spacing transformations
updated_df['overview'] = updated_df['overview'].apply(lambda x:x.split())
updated_df['genres'] = updated_df['genres'].apply(lambda x:[i.replace(" ", "") for i in x])
updated_df['keywords'] = updated_df['keywords'].apply(lambda x:[i.replace(" ", "") for i in x])
updated_df['cast'] = updated_df['cast'].apply(lambda x:[i.replace(" ", "") for i in x])
updated_df['crew'] = updated_df['crew'].apply(lambda x:[i.replace(" ", "") for i in x])
Title = updated_df['title'].str.strip('()').str.split(',')
updated_df.head(2)
# Out:
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
#
#                                                 cast             crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...   [JamesCameron]
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...  [GoreVerbinski]

# %%
#Add a new tag column consisting of all the columns except id
updated_df['tags'] = Title + updated_df['cast'] + updated_df['crew'] + updated_df['overview'] + updated_df['genres'] + updated_df['keywords']
updated_df.head(2)
# Out:
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
#
#                                                 cast             crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...   [JamesCameron]
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...  [GoreVerbinski]
#
#                                                 tags
# 0  [Avatar, SamWorthington, ZoeSaldana, Sigourney...
# 1  [Pirates of the Caribbean: At World's End, Joh...

# %%
#New Dataframe consisting only 3 columns, this will be helpful as we will perform bag of words and similarity...
#Only on 1 column to keep it simple
new_df = updated_df[['id', 'title',  'tags']]
new_df.head(2)
# Out:
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                 tags
# 0  [Avatar, SamWorthington, ZoeSaldana, Sigourney...
# 1  [Pirates of the Caribbean: At World's End, Joh...

# %%
#Check the Tags of 1st Movie
print(new_df['tags'][0])

#Convert the tags into a single string from multiple ones
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
#Convert the tags into lower case so that 'action' and 'Action' are not taken different
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

#Check the tags for the 1st Movie again
print('\n\n',new_df['tags'][0])

#Check the DataFrame Again
new_df.head(2)
# Out:
# ['Avatar', 'SamWorthington', 'ZoeSaldana', 'SigourneyWeaver', 'StephenLang', 'MichelleRodriguez', 'GiovanniRibisi', 'JoelDavidMoore', 'CCHPounder', 'WesStudi', 'LazAlonso', 'JamesCameron', 'In', 'the', '22nd', 'century,', 'a', 'paraplegic', 'Marine', 'is', 'dispatched', 'to', 'the', 'moon', 'Pandora', 'on', 'a', 'unique', 'mission,', 'but', 'becomes', 'torn', 'between', 'following', 'orders', 'and', 'protecting', 'an', 'alien', 'civilization.', 'Action', 'Adventure', 'Fantasy', 'ScienceFiction', 'cultureclash', 'future', 'spacewar', 'spacecolony', 'society', 'spacetravel', 'futuristic', 'romance', 'space', 'alien', 'tribe', 'alienplanet', 'cgi', 'marine', 'soldier', 'battle', 'loveaffair', 'antiwar', 'powerrelations', 'mindandsoul', '3d']
#
#
#  avatar samworthington zoesaldana sigourneyweaver stephenlang michellerodriguez giovanniribisi joeldavidmoore cchpounder wesstudi lazalonso jamescameron in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d
#       id                                     title  \
# 0  19995                                    Avatar
# 1    285  Pirates of the Caribbean: At World's End
#
#                                                 tags
# 0  avatar samworthington zoesaldana sigourneyweav...
# 1  pirates of the caribbean: at world's end johnn...

# %%
new_df.head(10)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
# 5     559                              Spider-Man 3
# 6   38757                                   Tangled
# 7   99861                   Avengers: Age of Ultron
# 8     767    Harry Potter and the Half-Blood Prince
# 9  209112        Batman v Superman: Dawn of Justice
#
#                                                 tags
# 0  avatar samworthington zoesaldana sigourneyweav...
# 1  pirates of the caribbean: at world's end johnn...
# 2  spectre danielcraig christophwaltz léaseydoux ...
# 3  the dark knight rises christianbale michaelcai...
# 4  john carter taylorkitsch lynncollins samantham...
# 5  spider-man 3 tobeymaguire kirstendunst jamesfr...
# 6  tangled zacharylevi mandymoore donnamurphy ron...
# 7  avengers: age of ultron robertdowneyjr. chrish...
# 8  harry potter and the half-blood prince danielr...
# 9  batman v superman: dawn of justice benaffleck ...

# %%
#This process is used to create a bag of words for each row, then with the similarity of the words in the tags from two..
#movies, the recommendation takes place through angle between the vectors in the 6900th dimension space
#Set the number of words we need in a tag, while ignoring simple english words like and, are, or, etc.
cv = CountVectorizer(max_features=4200, stop_words='english')

#Now we have passed the tags column to cv and assigned it to a vectors variable
vectors = cv.fit_transform(new_df['tags']).toarray()

#The 0 integer indicates that the particular word is not found in that row tag
#1 represents that this word is present in that row tag
print(vectors[1])
print(vectors.shape)
print(len(vectors))
print(len(cv.get_feature_names()))
# Out:
# [0 0 0 ... 0 0 0]
# (4806, 4200)
# 4806
# 4200

# %%
#Get all the unique words found in tags of all rows
cv.get_feature_names()
# Out:
# ['000',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1930s',
#  '1940s',
#  '1950s',
#  '1960s',
#  '1970s',
#  '1980s',
#  '19th',
#  '19thcentury',
#  '20',
#  '20th',
#  '24',
#  '25',
#  '30',
#  '3d',
#  '40',
#  '50',
#  '60',
#  'aaroneckhart',
#  'abandoned',
#  'abducted',
#  'abigailbreslin',
#  'ability',
#  'able',
#  'abuse',
#  'abusive',
#  'academy',
#  'accept',
#  'accepts',
#  'access',
#  'accident',
#  'accidentally',
#  'accompanied',
#  'account',
#  'accused',
#  'ace',
#  'act',
#  'action',
#  'actions',
#  'activist',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'adam',
#  'adambrody',
#  'adamsandler',
#  'adamscott',
#  'adaptation',
#  'addict',
#  'addicted',
#  'addiction',
#  'adewaleakinnuoye',
#  'adopted',
#  'adoption',
#  'adrienbrody',
#  'adult',
#  'adultery',
#  'adulthood',
#  'adults',
#  'advantage',
#  'adventure',
#  'adventures',
#  'advertising',
#  'advice',
#  'affair',
#  'affection',
#  'affections',
#  'afghanistan',
#  'africa',
#  'african',
#  'aftercreditsstinger',
#  'afterlife',
#  'agbaje',
#  'age',
#  'aged',
#  'agedifference',
#  'agency',
#  'agenda',
#  'agent',
#  'agents',
#  'aggressive',
#  'aging',
#  'ago',
#  'agree',
#  'agrees',
#  'ahead',
#  'aid',
#  'aidanquinn',
#  'aided',
#  'aids',
#  'ailing',
#  'air',
#  'airplane',
#  'airport',
#  'al',
#  'alabama',
#  'alanalda',
#  'alanarkin',
#  'alancumming',
#  'alanrickman',
#  'alantudyk',
#  'alaska',
#  'albert',
#  'albertbrooks',
#  'alcohol',
#  'alcoholic',
#  'alcoholism',
#  'alecbaldwin',
#  'alex',
#  'alfredmolina',
#  'alfrewoodard',
#  'ali',
#  'alice',
#  'alien',
#  'alieninvasion',
#  'alienlife',
#  'aliens',
#  'alike',
#  'alilarter',
#  'alive',
#  'allen',
#  'alliance',
#  'allied',
#  'allies',
#  'allisonjanney',
#  'allow',
#  'allows',
#  'ally',
#  'alpacino',
#  'alter',
#  'alternate',
#  'alzheimer',
#  'amanda',
#  'amandapeet',
#  'amandaseyfried',
#  'amazing',
#  'ambassador',
#  'amberheard',
#  'ambition',
#  'ambitious',
#  'ambulance',
#  'ambush',
#  'america',
#  'american',
#  'americanfootball',
#  'americans',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amy',
#  'amyadams',
#  'amypoehler',
#  'amysmart',
#  'analyst',
#  'ancient',
#  'anderson',
#  'andiemacdowell',
#  'andrew',
#  'android',
#  'andy',
#  'andygarcía',
#  'andysamberg',
#  'andyserkis',
#  'angel',
#  'angelabassett',
#  'angeles',
#  'angelinajolie',
#  'angels',
#  'anger',
#  'angry',
#  'animal',
#  'animalattack',
#  'animalhorror',
#  'animals',
#  'animated',
#  'animation',
#  'anjelicahuston',
#  'anna',
#  'annafaris',
#  'annakendrick',
#  'annapaquin',
#  'anne',
#  'annehathaway',
#  'anneheche',
#  'annemoss',
#  'annettebening',
#  'annie',
#  'annual',
#  'answer',
#  'answers',
#  'ant',
#  'anthology',
#  'anthony',
#  'anthonyanderson',
#  'anthonyhopkins',
#  'anthonymackie',
#  'anti',
#  'antics',
#  'antihero',
#  'antoniobanderas',
#  'antonyelchin',
#  'apart',
#  'apartheid',
#  'apartment',
#  'ape',
#  'apes',
#  'apocalypse',
#  'apocalyptic',
#  'appear',
#  'appears',
#  'apple',
#  'apprentice',
#  'approaches',
#  'april',
#  'archaeologist',
#  'architect',
#  'area',
#  'arena',
#  'arise',
#  'aristocrat',
#  'armed',
#  'arms',
#  'army',
#  'arnold',
#  'arnoldschwarzenegger',
#  'arrest',
#  'arrested',
#  'arrival',
#  'arrive',
#  'arrives',
#  'art',
#  'arthur',
#  'artificialintelligence',
#  'artist',
#  'artists',
#  'arts',
#  'ashley',
#  'ashleyjudd',
#  'ashtonkutcher',
#  'ask',
#  'asked',
#  'asks',
#  'aspiring',
#  'assassin',
#  'assassination',
#  'assassins',
#  'assault',
#  'assigned',
#  'assignment',
#  'assistant',
#  'asteroid',
#  'astronaut',
#  'asylum',
#  'athlete',
#  'atomicbomb',
#  'attack',
#  'attacked',
#  'attacks',
#  'attempt',
#  'attempts',
#  'attention',
#  'attitude',
#  'attorney',
#  'attraction',
#  'attractive',
#  'audience',
#  'audition',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'author',
#  'authorities',
#  'authority',
#  'auto',
#  'avenge',
#  'avoid',
#  'awaits',
#  'awakens',
#  'award',
#  'away',
#  'awry',
#  'babe',
#  'baby',
#  'bachelor',
#  'backdrop',
#  'bad',
#  'bahamas',
#  'balance',
#  'ball',
#  'ballet',
#  'band',
#  'bank',
#  'banker',
#  'bankrobbery',
#  'bar',
#  'barely',
#  'bargained',
#  'barn',
#  'barney',
#  'barry',
#  'barrylevinson',
#  'barrypepper',
#  'base',
#  'baseball',
#  'based',
#  'basedoncomicbook',
#  'basedonnovel',
#  'basedonplay',
#  'basedonstagemusical',
#  'basedontrueevents',
#  'basedontruestory',
#  'basedontvseries',
#  'basedonvideogame',
#  'basedonyoungadultnovel',
#  'basement',
#  'basketball',
#  'batman',
#  'battle',
#  'battlefield',
#  'battles',
#  'battling',
#  'bay',
#  'beach',
#  'bear',
#  'bears',
#  'beast',
#  'beat',
#  'beautiful',
#  'beauty',
#  'becominganadult',
#  'bed',
#  'beer',
#  'befriends',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'behavior',
#  'believe',
#  'believed',
#  'believes',
#  'beloved',
#  'ben',
#  'benaffleck',
#  'benchaplin',
#  'beneath',
#  'benedictcumberbatch',
#  'benfoster',
#  'beniciodeltoro',
#  'benjamin',
#  'benjaminbratt',
#  'benkingsley',
#  'benstiller',
#  'bent',
#  'berlin',
#  'berniemac',
#  'best',
#  'bestfriend',
#  'bet',
#  'beth',
#  'bethgrant',
#  'betrayal',
#  'bettemidler',
#  'better',
#  'betty',
#  'beverly',
#  'bible',
#  'big',
#  'bigger',
#  'biggest',
#  'biker',
#  'billcobbs',
#  'billhader',
#  'billionaire',
#  'billmurray',
#  'billnighy',
#  'billpaxton',
#  'billpullman',
#  'billy',
#  'billybobthornton',
#  'billyburke',
#  'billyconnolly',
#  'billycrudup',
#  'billycrystal',
#  'biography',
#  'bird',
#  'birth',
#  'birthday',
#  'bishop',
#  'bit',
#  'bite',
#  'bitter',
#  'bizarre',
#  'black',
#  'blackmail',
#  'blackpeople',
#  'blade',
#  'blind',
#  'block',
#  'blonde',
#  'blood',
#  'bloodsplatter',
#  'bloodthirsty',
#  'bloody',
#  'blow',
#  'blue',
#  'board',
#  'boat',
#  'bob',
#  'bobbalaban',
#  'bobby',
#  'bobbycannavale',
#  'bobbyfarrelly',
#  'bobhoskins',
#  'body',
#  'bodyguard',
#  'bokeemwoodbine',
#  'bollywood',
#  'bomb',
#  'bombing',
#  'bond',
#  'bone',
#  'bonniehunt',
#  'book',
#  'books',
#  'border',
#  'bored',
#  'boring',
#  'born',
#  'boss',
#  'boston',
#  'bound',
#  'bounty',
#  'bountyhunter',
#  'bourne',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'boyfriend',
#  'boys',
#  'braddourif',
#  'bradleycooper',
#  'bradpitt',
#  'brain',
#  'brave',
#  'bravery',
#  'brazil',
#  'break',
#  'breaking',
#  'breaks',
#  'breckinmeyer',
#  'brendanfraser',
#  'brendangleeson',
#  'brian',
#  'briancox',
#  'briandennehy',
#  'briandepalma',
#  'brianj',
#  'bride',
#  'bridge',
#  'brief',
#  'brien',
#  'bright',
#  'brilliant',
#  'bring',
#  'bringing',
#  'brings',
#  'brink',
#  'britain',
#  'british',
#  'britishsecretservice',
#  'brittanymurphy',
#  'broadway',
#  'broke',
#  'broken',
#  'brooklyn',
#  'brooks',
#  'brothel',
#  'brother',
#  'brotherbrotherrelationship',
#  'brothers',
#  'brothersisterrelationship',
#  'brought',
#  'brown',
#  'bruce',
#  'brucecampbell',
#  'brucedern',
#  'brucegreenwood',
#  'brucemcgill',
#  'brucewillis',
#  'brutal',
#  'brutality',
#  'brutally',
#  'bryancranston',
#  'buddies',
#  'buddy',
#  'buddycomedy',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'bully',
#  'bullying',
#  'bumbling',
#  'bunny',
#  'buried',
#  'burtreynolds',
#  'bus',
#  'bush',
#  'business',
#  'businessman',
#  'busy',
#  'butler',
#  'butterfly',
#  'buy',
#  'byrne',
#  'cabin',
#  'california',
#  'called',
#  'calls',
#  'calvin',
#  'came',
#  'camera',
#  'cameras',
#  'camerondiaz',
#  'camp',
#  'campaign',
#  'campbell',
#  'camping',
#  'campus',
#  'canada',
#  'canadian',
#  'cancer',
#  'candidate',
#  'cannibal',
#  'capable',
#  'capitalism',
#  'captain',
#  'captive',
#  'capture',
#  'captured',
#  'captures',
#  'car',
#  'caraccident',
#  'carchase',
#  'carcrash',
#  'card',
#  'care',
#  'career',
#  'carefree',
#  'careymulligan',
#  'caribbean',
#  'carl',
#  'carlagugino',
#  'carmen',
#  'carol',
#  'carrace',
#  'carrie',
#  'carry',
#  'carrying',
#  'cars',
#  'carter',
#  'cary',
#  'caryelwes',
#  'case',
#  'caseyaffleck',
#  'cash',
#  'casino',
#  'cast',
#  'castle',
#  'cat',
#  'catch',
#  'catches',
#  'cateblanchett',
#  'catherinekeener',
#  'catherineo',
#  'catherinezeta',
#  'catholic',
#  'catholicism',
#  'caught',
#  'cause',
#  'caused',
#  'causes',
#  'causing',
#  'cave',
#  'cedrictheentertainer',
#  'celebrate',
#  'celebration',
#  'celebrity',
#  'celiaweston',
#  'cellphone',
#  'center',
#  'centered',
#  'centers',
#  'central',
#  'centuries',
#  'century',
#  'certain',
#  'chain',
#  'chainsaw',
#  'challenge',
#  'challenged',
#  'challenges',
#  'champion',
#  'championship',
#  'chance',
#  'change',
#  'changed',
#  'changes',
#  'changing',
#  'channingtatum',
#  'chaos',
#  'chapter',
#  'character',
#  'characters',
#  'charge',
#  'charged',
#  'charismatic',
#  'charles',
#  'charlesdance',
#  'charlesdurning',
#  'charless',
#  'charlie',
#  'charliesheen',
#  'charlizetheron',
#  'charlotterampling',
#  'charltonheston',
#  'charm',
#  'charming',
#  'chase',
#  'chazzpalminteri',
#  'cheating',
#  'cheechmarin',
#  'cheerleader',
#  'chef',
#  'chemical',
#  'chevychase',
#  'chicago',
#  'chicken',
#  'chief',
#  'child',
#  'childabuse',
#  'childhood',
#  'children',
#  'chilling',
#  'chimcbride',
#  'china',
#  'chinese',
#  'chip',
#  'chiwetelejiofor',
#  'chloëgracemoretz',
#  'chloësevigny',
#  'chocolate',
#  'choice',
#  'choose',
#  'chosen',
#  'chris',
#  'chriscolumbus',
#  'chriscooper',
#  'chrisevans',
#  'chrishemsworth',
#  'chriso',
#  'chrispine',
#  'chrispratt',
#  'chrisrock',
#  'christ',
#  'christian',
#  'christianbale',
#  'christianity',
#  'christianslater',
#  'christinaapplegate',
#  'christinaricci',
#  'christinebaranski',
#  'christmas',
#  'christmasparty',
#  'christopher',
#  'christopherguest',
#  'christopherlee',
#  'christopherlloyd',
#  'christophermcdonald',
#  'christophermintz',
#  'christopherplummer',
#  'christopherwalken',
#  'chronicle',
#  'chronicles',
#  'chuck',
#  'church',
#  'cia',
#  'ciaránhinds',
#  'cillianmurphy',
#  'circle',
#  'circumstances',
#  'circus',
#  'citizens',
#  'city',
#  'civil',
#  'civilization',
#  'civilwar',
#  'claim',
#  'claims',
#  'claire',
#  'clairedanes',
#  'claireforlani',
#  'clan',
#  'clancybrown',
#  'clark',
#  'clarkgregg',
#  'clash',
#  'class',
#  'classic',
#  'classmate',
#  'classmates',
#  'claudevandamme',
#  'cleaduvall',
#  'clean',
#  'clear',
#  'clerk',
#  'client',
#  'cliffcurtis',
#  'cliftoncollinsjr',
#  'climbing',
#  'clinteastwood',
#  'cliveowen',
#  'clock',
#  'clone',
#  'clorisleachman',
#  'close',
#  'closer',
#  'club',
#  'clues',
#  'coach',
#  'coast',
#  'cocaine',
#  'code',
#  'cody',
#  'cold',
#  'coldwar',
#  'cole',
#  'colehauser',
#  'colinfarrell',
#  'colinfirth',
#  'collapse',
#  'colleague',
#  'colleagues',
#  'collect',
#  'collection',
#  'collector',
#  'college',
#  'collide',
#  'collins',
#  'collision',
#  'colmfeore',
#  'colonel',
#  'colony',
#  'colorful',
#  'coma',
#  'combat',
#  'come',
#  'comeback',
#  'comedian',
#  'comedy',
#  'comes',
#  'comic',
#  'coming',
#  'comingofage',
#  'comingout',
#  'command',
#  'commander',
#  'commercial',
#  'commit',
#  'commitment',
#  'committed',
#  'common',
#  'community',
#  'companion',
#  'company',
#  'compete',
#  'competing',
#  'competition',
#  'complete',
#  'completely',
#  'complex',
#  'complicated',
#  'complications',
#  'computer',
#  'conan',
#  'concert',
#  'condition',
#  'confidence',
#  'conflict',
#  'confront',
#  'congress',
#  'conman',
#  'connected',
#  'connection',
#  'connell',
#  'connienielsen',
#  'connor',
#  'conquer',
#  'conscience',
#  'consequences',
#  'conspiracy',
#  'construction',
#  'contact',
#  'contest',
#  'continue',
#  'continues',
#  'contract',
#  'control',
#  'controversial',
#  'convict',
#  'convicted',
#  'convince',
#  'convinced',
#  'convinces',
#  'cook',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  'cops',
#  'core',
#  'corporate',
#  'corporation',
#  'corpse',
#  'corrupt',
#  'corruption',
#  'cost',
#  'count',
#  'country',
#  'countryside',
#  'couple',
#  'couples',
#  'courage',
#  'courageous',
#  'course',
#  'court',
#  'courtcase',
#  'cousin',
#  'cover',
#  'covert',
#  'cowardliness',
#  'cowboy',
#  'crack',
#  'craig',
#  'craigrobinson',
#  'craigt',
#  'crash',
#  'crashes',
#  'crazy',
#  'create',
#  'created',
#  'creates',
#  'creature',
#  'creatures',
#  'crew',
#  'crime',
#  'crimefighter',
#  'crimes',
#  'criminal',
#  'criminals',
#  'crisis',
#  'crispinglover',
#  'critical',
#  'crocodile',
#  'cross',
#  'crossed',
#  'crosses',
#  'crown',
#  'cruel',
#  'cruelty',
#  'cruise',
#  'crush',
#  'crystal',
#  'cuba',
#  'cubagoodingjr',
#  'cult',
#  'cultfilm',
#  'cultural',
#  'culture',
#  'cultureclash',
#  'cure',
#  'curious',
#  'current',
#  'curse',
#  'custody',
#  'cut',
#  'cyberpunk',
#  'cyborg',
#  'dad',
#  'daily',
#  'dakotafanning',
#  'damage',
#  'dan',
#  'danaykroyd',
#  'dance',
#  'dancer',
#  'dancing',
#  'danger',
#  'dangerous',
#  'danhedaya',
#  'daniel',
#  'danielcraig',
#  'danny',
#  'dannydevito',
#  'dannyglover',
#  'dannyhuston',
#  'dannymcbride',
#  'dannytrejo',
#  'daring',
#  'dark',
#  'darkcomedy',
#  'darkest',
#  'darkness',
#  'darylhannah',
#  'dashmihok',
#  'date',
#  'dates',
#  'dating',
#  'daughter',
#  'daughters',
#  'dave',
#  'davefranco',
#  'david',
#  'davidarquette',
#  'davidcross',
#  'davidduchovny',
#  'davidkoechner',
#  'davidkrumholtz',
#  'davidmorse',
#  'davido',
#  'davidpaymer',
#  'davidspade',
#  'davidstrathairn',
#  'davidthewlis',
#  'davies',
#  'davis',
#  'dawn',
#  'daxshepard',
#  'day',
#  'days',
#  'dccomics',
#  'dea',
#  'dead',
#  'deadly',
#  'deal',
#  'dealer',
#  'dealers',
#  'dealing',
#  'deals',
#  'dean',
#  'death',
#  'deathofafriend',
#  'debt',
#  'decade',
#  'decades',
#  'deceased',
#  'deceit',
#  'deception',
#  'decide',
#  'decided',
#  'decides',
#  'decision',
#  'decisions',
#  'dedicated',
#  'deeds',
#  'deep',
#  'deeper',
#  'deeply',
#  'defeat',
#  'defend',
#  'defense',
#  'deliver',
#  'delroylindo',
#  'delusion',
#  'demands',
#  'demimoore',
#  'demon',
#  'demonic',
#  'demonicpossession',
#  'demons',
#  ...]

# %%
#Call the function from the library 
ps = PorterStemmer()

#How this function helps to reduce similar words 
print(ps.stem('adopt'))
print(ps.stem('adopted'))
print(ps.stem('adoption'))
print(ps.stem('adopts'))
# Out:
# adopt
# adopt
# adopt
# adopt

# %%
#A function to remove similar words from the tags column
def remover(text):
    final = []
    for i in text.split():
        final.append(ps.stem(i))
    return " ".join(final)

# %%
#Apply the function and see the results
new_df['tags'] = new_df['tags'].apply(remover)

#See the changes in first row of tags
print(new_df['tags'][1])

#Reassign the vectors to the newly transformed tags column
vectors = cv.fit_transform(new_df['tags']).toarray()
print(len(cv.get_feature_names())) #see if any change in length of unique names
cv.get_feature_names() #Get the feature names again
# Out:
# pirat of the caribbean: at world' end johnnydepp orlandobloom keiraknightley stellanskarsgård chowyun-fat billnighi geoffreyrush jackdavenport kevinmcn tomholland goreverbinski captain barbossa, long believ to be dead, ha come back to life and is head to the edg of the earth with will turner and elizabeth swann. but noth is quit as it seems. adventur fantasi action ocean drugabus exoticisland eastindiatradingcompani loveofone'slif traitor shipwreck strongwoman ship allianc calypso afterlif fighter pirat swashbuckl aftercreditssting
# 4200
# ['000',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '18th',
#  '19',
#  '1930',
#  '1940',
#  '1950',
#  '1960',
#  '1970',
#  '1980',
#  '1990',
#  '19th',
#  '19thcenturi',
#  '20',
#  '20th',
#  '24',
#  '25',
#  '30',
#  '300',
#  '3d',
#  '40',
#  '50',
#  '60',
#  '70',
#  'aaron',
#  'aaroneckhart',
#  'aarontaylor',
#  'abandon',
#  'abduct',
#  'abigailbreslin',
#  'abil',
#  'abl',
#  'abov',
#  'abus',
#  'academi',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'accompani',
#  'accomplish',
#  'account',
#  'accus',
#  'ace',
#  'achiev',
#  'act',
#  'action',
#  'activ',
#  'activist',
#  'actor',
#  'actress',
#  'actual',
#  'adam',
#  'adambrodi',
#  'adamsandl',
#  'adamscott',
#  'adapt',
#  'add',
#  'addict',
#  'adewaleakinnuoye',
#  'adjust',
#  'admir',
#  'admit',
#  'adolesc',
#  'adopt',
#  'ador',
#  'adrienbrodi',
#  'adult',
#  'adulteri',
#  'adulthood',
#  'advanc',
#  'adventur',
#  'adventure',
#  'advertis',
#  'advic',
#  'affair',
#  'affect',
#  'afghanistan',
#  'africa',
#  'african',
#  'aftercreditssting',
#  'afterlif',
#  'aftermath',
#  'ag',
#  'agbaj',
#  'age',
#  'agediffer',
#  'agency',
#  'agenda',
#  'agent',
#  'aggress',
#  'ago',
#  'agre',
#  'ahead',
#  'aid',
#  'aidanquinn',
#  'ail',
#  'aim',
#  'air',
#  'airplan',
#  'airport',
#  'al',
#  'alabama',
#  'alanalda',
#  'alanarkin',
#  'alancum',
#  'alanrickman',
#  'alantudyk',
#  'alaska',
#  'albert',
#  'albertbrook',
#  'alcohol',
#  'alecbaldwin',
#  'alex',
#  'alfredmolina',
#  'alfrewoodard',
#  'ali',
#  'alic',
#  'alice',
#  'alien',
#  'alieninvas',
#  'alienlife',
#  'alilart',
#  'aliv',
#  'alive',
#  'allen',
#  'alli',
#  'allianc',
#  'allisonjanney',
#  'allow',
#  'alon',
#  'alongsid',
#  'alpacino',
#  'alpha',
#  'alreadi',
#  'alter',
#  'altern',
#  'alway',
#  'alzheimer',
#  'amanda',
#  'amandapeet',
#  'amandaseyfri',
#  'amateur',
#  'amaz',
#  'ambassador',
#  'amberheard',
#  'ambit',
#  'ambiti',
#  'ambul',
#  'ambush',
#  'america',
#  'american',
#  'americanfootbal',
#  'amid',
#  'amidst',
#  'amnesia',
#  'amp',
#  'amus',
#  'amyadam',
#  'amypoehl',
#  'amysmart',
#  'analyst',
#  'anarchiccomedi',
#  'ancient',
#  'anderson',
#  'andi',
#  'andiemacdowel',
#  'andrew',
#  'android',
#  'andygarcía',
#  'andysamberg',
#  'andyserki',
#  'angel',
#  'angelabassett',
#  'angeles',
#  'angelinajoli',
#  'anger',
#  'angri',
#  'ani',
#  'anim',
#  'animalattack',
#  'animalhorror',
#  'anjelicahuston',
#  'ann',
#  'anna',
#  'annafari',
#  'annakendrick',
#  'annapaquin',
#  'annasophiarobb',
#  'anne',
#  'annehathaway',
#  'annehech',
#  'annemoss',
#  'annetteben',
#  'anni',
#  'announc',
#  'annual',
#  'anonym',
#  'anoth',
#  'answer',
#  'ant',
#  'antholog',
#  'anthoni',
#  'anthonyanderson',
#  'anthonyhopkin',
#  'anthonymacki',
#  'anthropomorph',
#  'anti',
#  'antihero',
#  'antoniobandera',
#  'antonyelchin',
#  'anyon',
#  'anyth',
#  'apart',
#  'apartheid',
#  'apartment',
#  'ape',
#  'apocalyps',
#  'apocalypt',
#  'appar',
#  'appear',
#  'appoint',
#  'appreci',
#  'apprentic',
#  'approach',
#  'april',
#  'arab',
#  'archaeologist',
#  'architect',
#  'arctic',
#  'area',
#  'arena',
#  'aris',
#  'aristocrat',
#  'arm',
#  'armi',
#  'armor',
#  'armsdeal',
#  'armstrong',
#  'army',
#  'arnold',
#  'arnoldschwarzenegg',
#  'arrang',
#  'arrest',
#  'arriv',
#  'art',
#  'arthur',
#  'artificialintellig',
#  'artist',
#  'ash',
#  'ashley',
#  'ashleyjudd',
#  'ashtonkutch',
#  'asia',
#  'ask',
#  'aspir',
#  'assassin',
#  'assault',
#  'assign',
#  'assist',
#  'assistant',
#  'associ',
#  'assum',
#  'asteroid',
#  'astronaut',
#  'asylum',
#  'athlet',
#  'atomicbomb',
#  'attack',
#  'attempt',
#  'attend',
#  'attent',
#  'attitud',
#  'attorney',
#  'attract',
#  'audienc',
#  'audit',
#  'august',
#  'aunt',
#  'austin',
#  'australia',
#  'australian',
#  'author',
#  'auto',
#  'aveng',
#  'avoid',
#  'await',
#  'awaken',
#  'award',
#  'away',
#  'awkward',
#  'awri',
#  'awry',
#  'babe',
#  'babi',
#  'baby',
#  'bachelor',
#  'backdrop',
#  'background',
#  'bad',
#  'bag',
#  'bahama',
#  'bail',
#  'balanc',
#  'ball',
#  'ballet',
#  'band',
#  'bandit',
#  'banish',
#  'bank',
#  'banker',
#  'bankrobberi',
#  'bar',
#  'bare',
#  'bargain',
#  'barn',
#  'barney',
#  'barri',
#  'barrylevinson',
#  'barrypepp',
#  'bas',
#  'base',
#  'basebal',
#  'basedoncomicbook',
#  'basedonnovel',
#  'basedonplay',
#  'basedonstagemus',
#  'basedontrueev',
#  'basedontruestori',
#  'basedontvseri',
#  'basedonvideogam',
#  'basedonyoungadultnovel',
#  'basement',
#  'basketbal',
#  'batman',
#  'battl',
#  'battle',
#  'battlefield',
#  'bay',
#  'beach',
#  'bear',
#  'beast',
#  'beat',
#  'beauti',
#  'beautiful',
#  'becam',
#  'becaus',
#  'becom',
#  'becominganadult',
#  'bed',
#  'beer',
#  'befor',
#  'befriend',
#  'began',
#  'begin',
#  'behavior',
#  'belief',
#  'believ',
#  'bell',
#  'belong',
#  'belov',
#  'ben',
#  'benaffleck',
#  'bend',
#  'beneath',
#  'benedictcumberbatch',
#  'benefit',
#  'benfost',
#  'beniciodeltoro',
#  'benjamin',
#  'benjaminbratt',
#  'benkingsley',
#  'bennett',
#  'benstil',
#  'bent',
#  'berlin',
#  'bernardle',
#  'berniemac',
#  'best',
#  'bestfriend',
#  'bet',
#  'beth',
#  'bethgrant',
#  'betray',
#  'bettemidl',
#  'better',
#  'betti',
#  'beverli',
#  'bibl',
#  'big',
#  'bigger',
#  'biggest',
#  'biker',
#  'billcobb',
#  'billhad',
#  'billi',
#  'billionair',
#  'billmurray',
#  'billnighi',
#  'billpaxton',
#  'billpullman',
#  'billybobthornton',
#  'billyburk',
#  'billyconnolli',
#  'billycrudup',
#  'billycryst',
#  'biographi',
#  'bird',
#  'birth',
#  'birthday',
#  'bisexu',
#  'bishop',
#  'bit',
#  'bite',
#  'bitter',
#  'bizarr',
#  'black',
#  'blackmail',
#  'blackpeopl',
#  'blade',
#  'blame',
#  'blend',
#  'blind',
#  'bliss',
#  'block',
#  'blond',
#  'blood',
#  'bloodi',
#  'bloodsplatt',
#  'bloodthirsti',
#  'blow',
#  'blue',
#  'board',
#  'boat',
#  'bob',
#  'bobbalaban',
#  'bobbi',
#  'bobbycannaval',
#  'bobbyfarrelli',
#  'bobgunton',
#  'bobhoskin',
#  'bodi',
#  'body',
#  'bodyguard',
#  'bokeemwoodbin',
#  'bold',
#  'bollywood',
#  'bomb',
#  'bond',
#  'bone',
#  'bonniehunt',
#  'book',
#  'border',
#  'bore',
#  'born',
#  'boss',
#  'boston',
#  'bound',
#  'bounti',
#  'bountyhunt',
#  'bourn',
#  'box',
#  'boxer',
#  'boy',
#  'boyfriend',
#  'boys',
#  'braddourif',
#  'bradleycoop',
#  'bradpitt',
#  'brain',
#  'brand',
#  'brave',
#  'braveri',
#  'brazil',
#  'brazilian',
#  'break',
#  'breckinmey',
#  'brendanfras',
#  'brendangleeson',
#  'brettratn',
#  'brian',
#  'briancox',
#  'briandennehi',
#  'briandepalma',
#  'brianj',
#  'bride',
#  'bridesmaid',
#  'bridg',
#  'brief',
#  'brielarson',
#  'brien',
#  'bright',
#  'brilliant',
#  'bring',
#  'brink',
#  'britain',
#  'british',
#  'britishsecretservic',
#  'brittanymurphi',
#  'broadway',
#  'broke',
#  'broken',
#  'brook',
#  'brooklyn',
#  'broom',
#  'brothel',
#  'brother',
#  'brotherbrotherrelationship',
#  'brothers',
#  'brothersisterrelationship',
#  'brought',
#  'brown',
#  'bruce',
#  'brucecampbel',
#  'brucedern',
#  'brucegreenwood',
#  'brucemcgil',
#  'brucewilli',
#  'brutal',
#  'bryancranston',
#  'bu',
#  'buck',
#  'bud',
#  'buddi',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'bullet',
#  'bulli',
#  'bumbl',
#  'bunni',
#  'buri',
#  'burn',
#  'burtreynold',
#  'bush',
#  'busi',
#  'business',
#  'businessman',
#  'bust',
#  'butler',
#  'butterfli',
#  'buy',
#  'byrn',
#  'cabin',
#  'caesar',
#  'cal',
#  'california',
#  'calvin',
#  'came',
#  'camera',
#  'camerondiaz',
#  'camp',
#  'campaign',
#  'campu',
#  'canada',
#  'canadian',
#  'cancer',
#  'candid',
#  'cannib',
#  'capabl',
#  'capit',
#  'captain',
#  'captiv',
#  'captur',
#  'car',
#  'caraccid',
#  'carchas',
#  'carcrash',
#  'card',
#  'care',
#  'career',
#  'careymulligan',
#  'caribbean',
#  'carl',
#  'carlagugino',
#  'carmen',
#  'carol',
#  'carrac',
#  'carri',
#  'carrie',
#  'carter',
#  'cary',
#  'caryelw',
#  'case',
#  'caseyaffleck',
#  'cash',
#  'casino',
#  'cast',
#  'castl',
#  'cat',
#  'cataclysm',
#  'catastroph',
#  'catch',
#  'cateblanchett',
#  'catherinekeen',
#  'catherineo',
#  'catherinezeta',
#  'cathol',
#  'catholic',
#  'caught',
#  'caus',
#  'cave',
#  'cedrictheentertain',
#  'celebr',
#  'celiaweston',
#  'cellphon',
#  'cemeteri',
#  'center',
#  'central',
#  'centuri',
#  'century',
#  'certain',
#  'chadmichaelmurray',
#  'chain',
#  'chainsaw',
#  'challeng',
#  'champion',
#  'championship',
#  'chanc',
#  'chance',
#  'chang',
#  'channingtatum',
#  'chao',
#  'chaos',
#  'chapter',
#  'charact',
#  'character',
#  'characters',
#  'charg',
#  'charismat',
#  'charl',
#  'charlesd',
#  'charlesdurn',
#  'charless',
#  'charli',
#  'charlie',
#  'charliesheen',
#  'charlizetheron',
#  'charlotterampl',
#  'charltonheston',
#  'charm',
#  'chase',
#  'chazzpalminteri',
#  'cheat',
#  'cheechmarin',
#  'cheerlead',
#  'chef',
#  'chemic',
#  'chevychas',
#  'chicago',
#  'chicken',
#  'chief',
#  'child',
#  'childabus',
#  'childhood',
#  'children',
#  'chill',
#  'chimcbrid',
#  'china',
#  'chines',
#  'chip',
#  'chiwetelejiofor',
#  'chloëgracemoretz',
#  'chloësevigni',
#  'chocol',
#  'choic',
#  'choos',
#  'chosen',
#  'chri',
#  'chriscolumbu',
#  'chriscoop',
#  'chrisevan',
#  'chrishemsworth',
#  'chrisklein',
#  'chriso',
#  'chrispin',
#  'chrispratt',
#  'chrisrock',
#  'christ',
#  'christian',
#  'christianbal',
#  'christianslat',
#  'christinaappleg',
#  'christinaricci',
#  'christinebaranski',
#  'christma',
#  'christmas',
#  'christmasparti',
#  'christoph',
#  'christopherguest',
#  'christopherle',
#  'christopherlloyd',
#  'christophermcdonald',
#  'christophermintz',
#  'christopherplumm',
#  'christopherwalken',
#  'christophwaltz',
#  'chronicl',
#  'chuck',
#  'church',
#  'cia',
#  'ciaránhind',
#  'cillianmurphi',
#  'cinderella',
#  'cinema',
#  'circl',
#  'circu',
#  'circumst',
#  'citi',
#  'citizen',
#  'city',
#  'civil',
#  'civilian',
#  'civilwar',
#  'claim',
#  'clair',
#  'clairedan',
#  'claireforlani',
#  'clan',
#  'clancybrown',
#  'clark',
#  'clarkgregg',
#  'clash',
#  'class',
#  'classic',
#  'classmat',
#  'classroom',
#  'claudevandamm',
#  'cleaduval',
#  'clean',
#  'clear',
#  'clerk',
#  'client',
#  'cliffcurti',
#  'cliftoncollinsjr',
#  'climat',
#  'climb',
#  'clinteastwood',
#  'cliveowen',
#  'clock',
#  'clone',
#  'clorisleachman',
#  'close',
#  'closer',
#  'clown',
#  'club',
#  'clue',
#  'coach',
#  'coast',
#  'cocain',
#  'code',
#  'cohen',
#  'col',
#  'cold',
#  'coldwar',
#  'cole',
#  'colehaus',
#  'colinfarrel',
#  'colinfirth',
#  'collaps',
#  'colleagu',
#  'collect',
#  'collector',
#  'colleg',
#  'college',
#  'collid',
#  'collin',
#  'collis',
#  'colmfeor',
#  'colonel',
#  'coloni',
#  'color',
#  'coma',
#  'combat',
#  'combin',
#  'come',
#  'comeback',
#  'comedi',
#  'comedian',
#  'comedy',
#  'comfort',
#  'comic',
#  'coming',
#  'comingofag',
#  'comingout',
#  'command',
#  'commando',
#  'commerci',
#  'commit',
#  'common',
#  'commun',
#  'compani',
#  'companion',
#  'company',
#  'compet',
#  'competit',
#  'competition',
#  'complet',
#  'complex',
#  'complic',
#  'compos',
#  'compton',
#  'comput',
#  'conan',
#  'concern',
#  'concert',
#  'condit',
#  'confess',
#  'confid',
#  'conflict',
#  'confront',
#  'confus',
#  'congress',
#  'conman',
#  'connect',
#  'connel',
#  'connienielsen',
#  'connor',
#  'conquer',
#  'consequ',
#  'consequences',
#  'consid',
#  'conspir',
#  'conspiraci',
#  'constant',
#  'constantli',
#  'construct',
#  'consum',
#  'contact',
#  'contain',
#  'contend',
#  'contest',
#  'continu',
#  'contract',
#  'control',
#  'controversi',
#  'convent',
#  'convers',
#  'convict',
#  'convinc',
#  'cook',
#  'cool',
#  'cooper',
#  'cop',
#  'cope',
#  'core',
#  'corner',
#  'corpor',
#  'corps',
#  'corrupt',
#  'cost',
#  'costum',
#  'count',
#  'countri',
#  'country',
#  'countrysid',
#  'coupl',
#  'couple',
#  'courag',
#  'cours',
#  'court',
#  'courtcas',
#  'cousin',
#  'cover',
#  'covert',
#  'cowardli',
#  'cowboy',
#  'crack',
#  'craft',
#  'craig',
#  'craigrobinson',
#  'craigt',
#  'crash',
#  'crazi',
#  'creat',
#  'creation',
#  'creator',
#  'creatur',
#  'creatures',
#  'crew',
#  'cri',
#  'crime',
#  'crimefight',
#  'crimin',
#  'criminals',
#  'crisi',
#  'crisis',
#  'crispinglov',
#  'critic',
#  'crocodil',
#  'crook',
#  'cross',
#  'crown',
#  'cruel',
#  'cruis',
#  'crusad',
#  'crush',
#  'crystal',
#  'cuba',
#  'cubagoodingjr',
#  'cult',
#  'cultfilm',
#  'cultur',
#  'cultureclash',
#  'cure',
#  'current',
#  'curs',
#  'curse',
#  'custodi',
#  'custom',
#  'cut',
#  'cyberpunk',
#  'cyborg',
#  'cynic',
#  'dad',
#  'daili',
#  'dakotafan',
#  'damag',
#  'dan',
#  'danaykroyd',
#  'danc',
#  'dancer',
#  'danger',
#  'danhedaya',
#  'daniel',
#  'danielcraig',
#  'danielradcliff',
#  'danni',
#  'dannydevito',
#  'dannyglov',
#  'dannyhuston',
#  'dannymcbrid',
#  'dannytrejo',
#  'dare',
#  'dark',
#  'darkcomedi',
#  'darkest',
#  'darylhannah',
#  'dashmihok',
#  'date',
#  'daughter',
#  'dave',
#  'davefranco',
#  'davi',
#  'david',
#  'davidarquett',
#  'davidcross',
#  'davidduchovni',
#  'davidfinch',
#  'davidkoechn',
#  'davidkrumholtz',
#  'davidmors',
#  'davido',
#  'davidpaym',
#  'davidspad',
#  'davidstrathairn',
#  'davidthewli',
#  'dawn',
#  'daxshepard',
#  'day',
#  'days',
#  'dccomic',
#  'dea',
#  'dead',
#  'deadli',
#  'deaf',
#  'deal',
#  'dealer',
#  'dean',
#  'death',
#  'deathofafriend',
#  'deathpenalti',
#  'debt',
#  'debut',
#  'decad',
#  'deceas',
#  'deceit',
#  'decept',
#  'decid',
#  'decis',
#  'declar',
#  'dedic',
#  'deed',
#  'deep',
#  'deeper',
#  'deepli',
#  'defeat',
#  'defend',
#  'defens',
#  'defi',
#  'deliv',
#  ...]

# %%
#Find the similarity of the vectors
similarity = cosine_similarity(vectors)
print(similarity.shape)
print(similarity[1])
# Out:
# (4806, 4806)
# [0.07254763 1.         0.05354796 ... 0.04095301 0.0204765  0.02067246]

# %%
similarity
# Out:
# array([[1.        , 0.07254763, 0.08740748, ..., 0.04456565, 0.        ,
#         0.        ],
#        [0.07254763, 1.        , 0.05354796, ..., 0.04095301, 0.0204765 ,
#         0.02067246],
#        [0.08740748, 0.05354796, 1.        , ..., 0.02467069, 0.        ,
#         0.        ],
#        ...,
#        [0.04456565, 0.04095301, 0.02467069, ..., 1.        , 0.03773585,
#         0.05714545],
#        [0.        , 0.0204765 , 0.        , ..., 0.03773585, 1.        ,
#         0.07619393],
#        [0.        , 0.02067246, 0.        , ..., 0.05714545, 0.07619393,
#         1.        ]])

# %%
#How the reverse sorted similarity list looks like
sorted(similarity[0], reverse=True)
# Out:
# [1.0,
#  0.3008967382970352,
#  0.2699527623995086,
#  0.24924389543835837,
#  0.24525573579398632,
#  0.2433321316961438,
#  0.24210006235312614,
#  0.2421000623531261,
#  0.24002133617819926,
#  0.23231373170253145,
#  0.23009750575655635,
#  0.2278389747471728,
#  0.220755392844174,
#  0.21764287503300353,
#  0.21526419295572297,
#  0.21459876881973805,
#  0.21073180760588114,
#  0.20942695414584772,
#  0.20751433915982237,
#  0.20519567041703082,
#  0.20437977982832192,
#  0.2029530274475215,
#  0.20277677641345318,
#  0.20277677641345318,
#  0.202677836775256,
#  0.2024645717996314,
#  0.20073876713674155,
#  0.19867985355975662,

#  0.0978231976089037,
#  0.0978231976089037,
#  0.0978231976089037,
#  0.0978231976089037,
#  0.0978231976089037,
#  0.0978231976089037,
#  0.09764582085806336,
#  0.09733285267845754,
#  0.09733285267845754,
#  0.09733285267845754,
#  0.09733285267845754,
#  0.09733285267845754,
#  0.09733285267845754,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.0967301666813349,
#  0.09626070358206487,
#  0.09626070358206487,
#  0.09567297464698798,
#  0.09558988911273408,
#  0.09558988911273408,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09544271444636668,
#  0.09493290614465533,
#  0.09464970485606021,
#  0.09464970485606021,
#  0.09464970485606021,
#  0.09464970485606021,
#  0.09464970485606021,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.09365858115816941,
#  0.0936585811581694,
#  0.09304036594559835,
#  0.09269795493186431,
#  0.09269795493186431,
#  0.09269795493186431,
#  0.09269795493186431,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09197090092274487,
#  0.09183979479633063,
#  0.09176629354822471,
#  0.09176629354822471,
#  0.09176629354822471,
#  0.09176629354822471,
#  0.09125667909262308,
#  0.09086217008485092,
#  0.09086217008485092,
#  0.09086217008485092,
#  0.09086217008485092,
#  0.09068453126375145,
#  0.09068453126375145,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09037128496931669,
#  0.09033950326094178,
#  0.09012301173931252,
#  0.09012301173931252,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.08998425413316952,
#  0.0891313035643173,
#  0.0891313035643173,
#  0.0891313035643173,
#  0.0891313035643173,
#  0.08903057122447033,
#  0.08903057122447033,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08885233166386385,
#  0.08830215713766959,
#  0.08749572785196143,
#  0.08749572785196143,
#  0.08749572785196143,
#  0.08746392856766495,
#  0.08740748201220976,
#  0.08740748201220976,
#  0.08740748201220976,
#  0.08740748201220976,
#  0.08740748201220976,
#  0.08740748201220976,
#  0.08671099695241201,
#  0.08671099695241201,
#  0.08671099695241201,
#  0.08671099695241201,
#  0.08603090020146065,
#  0.08603090020146065,
#  0.08603090020146065,
#  0.08603090020146065,
#  0.08603090020146065,
#  0.08594700851870801,
#  0.08594700851870801,
#  0.08594700851870801,
#  0.08520286456846099,
#  0.08520286456846099,
#  0.08520286456846099,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08471737420873576,
#  0.08447772061910234,
#  0.08447772061910234,
#  0.08447772061910234,
#  0.08447772061910234,
#  0.08447772061910234,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.0837707816583391,
#  0.08365931017628184,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.08346223261119858,
#  0.0830812984794528,
#  0.0830812984794528,
#  0.0830812984794528,
#  0.08240856434303293,
#  0.08240856434303293,
#  0.08240856434303293,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08226127456606226,
#  0.08175191193132876,
#  0.08175191193132876,
#  0.08175191193132876,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08111071056538127,
#  0.08070817353691266,
#  0.08048436365855338,
#  0.08048436365855338,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.08000711205939975,
#  0.07987230638308718,
#  0.07987230638308718,
#  0.07987230638308718,
#  0.07987230638308718,
#  0.0792740035289418,
#  0.0792740035289418,
#  0.0792740035289418,
#  0.0792740035289418,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07894736842105264,
#  0.07868894753646337,
#  0.07868894753646337,
#  0.07868894753646337,
#  0.07868894753646337,
#  0.07868894753646337,
#  0.07868894753646337,
#  0.07817962860855646,
#  0.0781166566864507,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07792865001991967,
#  0.07755667343294813,
#  0.07733602811121826,
#  0.0770085628656519,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07694837640638656,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.07647191129018727,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.076004188790721,
#  0.07594632491572426,
#  0.07594632491572426,
#  0.07594632491572426,
#  0.07563612760200647,
#  0.07563612760200647,
#  0.07543142864047142,
#  0.07543142864047142,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07509392614826384,
#  0.07492686492653551,
#  0.07492686492653551,
#  0.07492686492653551,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07443229275647868,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.07421560439929402,
#  0.0734718358370645,
#  0.0734718358370645,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07336739820667779,
#  0.07300534327409847,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100118,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07254762501100116,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07175473098524099,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07098727864204515,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07079923254047887,
#  0.07038153430777869,
#  0.07038153430777869,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862707,
#  0.07024393586862705,
#  0.06997114285413196,
#  0.0695678476053965,
#  0.0695678476053965,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06952346619889824,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06917144638660747,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06882472016116853,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06814662756363819,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06765100914917384,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.06748819059987714,
#  0.0672863110252489,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.06684847767323797,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.0662266178532522,
#  0.06622661785325219,
#  0.06622661785325219,
#  0.06622661785325219,
#  0.06622661785325219,
#  0.06622661785325219,
#  0.06622661785325219,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06562179588897107,
#  0.06557412294705281,
#  0.065033247714309,
#  0.065033247714309,
#  0.065033247714309,
#  0.065033247714309,
#  0.065033247714309,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06488856845230502,
#  0.06446025638903101,
#  0.06446025638903101,
#  0.06446025638903101,
#  0.06446025638903101,
#  0.06446025638903101,
#  0.06424925662032356,
#  0.06393660631422403,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06390214842634574,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06362847629757779,
#  0.06335829046432676,
#  0.06335829046432676,
#  0.06335829046432676,
#  0.06282808624375433,
#  0.06282808624375433,
#  0.06282808624375433,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.06243905410544627,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.0623109738595896,
#  0.061806423257274694,
#  0.061806423257274694,
#  0.061806423257274694,
#  0.061806423257274694,
#  0.061806423257274694,
#  0.061806423257274694,
#  0.06180642325727469,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.06131393394849658,
#  0.061313933948496574,
#  0.061313933948496574,
#  0.061313933948496574,
#  0.061313933948496574,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.060833032924035954,
#  0.0607737125462764,
#  0.060363272743915036,
#  0.060363272743915036,
#  0.060363272743915036,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.0602475233128778,
#  0.05990422978731538,
#  ...]

# %%
#Function to recommend movies based on the input movie
def recommendme(movie):
    movie_index = new_df[new_df['title'] == movie].index[0] #Get the index of the input movie from the new_df and not movie id
    distances = similarity[movie_index] #Compute the similarity of this film with all the other films
    #Give the top 10 movies from reverse sorted list with highest similarity
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:11]
    #Get the titles of each indexes we enumerated to find the movie
    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %%
#This is how emumerated sorted list looks like with the index corresponding to the new_df
#This kind of data is stored in the movie_list from the above function
sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x:x[1])[1:6]
# Out:
# [(1216, 0.3008967382970352),
#  (2409, 0.2699527623995086),
#  (507, 0.24924389543835837),
#  (1194, 0.24525573579398632),
#  (539, 0.2433321316961438)]

# %%
#Run the function recommendme to get Movie recommendation
recommendme("Spider-Man")
# Out:
# Spider-Man 3
# Spider-Man 2
# The Amazing Spider-Man 2
# Arachnophobia
# The Amazing Spider-Man
# Eight Legged Freaks
# Along Came a Spider
# Kingdom of the Spiders
# Radio
# 21 Jump Street

# %%
#End of Movie Content Based Recommendation System Program
